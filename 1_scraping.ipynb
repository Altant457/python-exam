# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

response = requests.get('https://store.steampowered.com/search/?sort_by=Released_DESC&category1=998&supportedlang=english&ndl=1')

soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Exctract individual game links on the search page

result_rows_div = soup.find('div', id='search_resultsRows')

a_elements = result_rows_div.find_all('a')

links_list = [] # links to every game

for a_element in a_elements:
    link = a_element['href']
    links_list.append(link)

# %%
# extract title, description and genres on individual game pages
game_data = []

for link in links_list:
    response = requests.get(link)
    soup = BeautifulSoup(response.content, 'html.parser')

    game_title = soup.find('div', {'class': 'apphub_AppName'}).get_text(strip=True)
    game_description = soup.find('div', {'class': 'game_description_snippet'}).get_text(strip=True)

    genre_div = soup.find('div', id='genresAndManufacturer')
    first_span = genre_div.find('span')

    game_genre_list = []  # Create a new list for each game

    if first_span:
        a_elements_in_span = first_span.find_all('a')
        for a_element in a_elements_in_span:
            genre = a_element.text
            game_genre_list.append(genre)

    game_data.append({'Title': game_title, 'Description': game_description, 'Genre': game_genre_list})

df = pd.DataFrame(game_data)

df
# Out:
#                                       Title  \
# 0                                  TaskPals
# 1                                Ghost Maze
# 2                             Nature Hunter
# 3                                 SpaceWorm
# 4                       ReXueLinHun Dynasty
# 5                          Cards & Tankards
# 6             REDSTORY and the Last Glimmer
# 7                              ZOMBIAX EVIL
# 8      Frontline: Panzers & Generals Vol. I
# 9                              Gun and Girl
# 10                           Kung Fu Legend
# 11                                Anna Girl
# 12                             Tuk Tuk Race
# 13                                  Bat Boy
# 14  Marlon’s Mystery: The darkside of crime
# 15                              Tiny Island
# 16                              Hit the Bit
# 17                 Idle Taoist Mage Warrior
# 18        おいでませ、こくりさん - Welcome Kokurisan -
# 19                       Golf with the Lads
# 20                             FAKE SIGNALS
# 21                     AOISHIRO HD REMASTER
# 22                      AKAIITO HD REMASTER
# 23                         Missing Critters
# 24                                INTERNULL
# 25               International Secret Agent
# 26                           Hot Heat Reset
# 27                              Cube Heroes
# 28                           Astro Traveler
# 29                           Zombie Defense
# 30                              AngelStrike
# 31                                    Koler
# 32                           ForeVR Bowl VR
# 33               Twilight Struggle: Red Sea
# 34                   Five Nights at Tinky's
# 35                             Dark Quest 3
# 36                                The Druid
# 37                         8/8/88 Needle AL
# 38                             Rite as Rain
# 39                             Dojo Assault
# 40                         Metro Manager LA
# 41                           Bounda Forever
# 42                            Start Link VR
# 43                     No Legs? No Problem!
# 44       Travel Cuisine Collector's Edition
# 45                                 Only Up!
# 46              Kizuna AI - Touch the Beat!
# 47                        SHINOBI NON GRATA
# 48          BATSUGUN Saturn Tribute Boosted
# 49                             Rift Rangers
#
#                                           Description  \
# 0   TaskPals is a simple companion app that brings...
# 1   Embark on this small adventure to conquer a tr...
# 2   Realism, craftsmanship, self-regulating vegeta...
# 3   SpaceWorm is a casual retro game where you eat...
# 4   Start with a knife, no need to brush equipment...
# 5   Grab a drink, invite your friends and ready yo...
# 6   REDSTORY and the Last Glimmer tells the story ...
# 7   Survive as long as possible against the zombie...
# 8   Experience the thrill of commanding your army ...
# 9   Experience the combination of shooting and puz...
# 10  An open-world adventure with lots of humor and...
# 11  This is a casual jigsaw puzzle game, the game ...
# 12    Let's race a tuk-tuk through beautiful scenery!
# 13  Ryosuke isn't just your regular high-school ki...
# 14  Marlon's Mystery will test your skills as an i...
# 15  A meditative God simulator in VR with a strate...
# 16  Hit the Bit is an action-packed PvP game, wher...
# 17  Are you familiar with the three major professi...
# 18  A short novel game with ASMR starring VTuber "...
# 19  A short project aimed at bringing a fun minigo...
# 20  FAKE SIGNALS is an action hybrid rogue-lite th...
# 21  Japanese adventure game. Aoi Shiro is an adven...
# 22  Japanese adventure game. Set in the present ag...
# 23  Embark on a delightful adventure and seek out ...
# 24  After waking up in the facilities of a once-su...
# 25  Save the world from a mad scientist's evil pla...
# 26  A fast-paced maze action game where you play a...
# 27  A Magic Cube Roguelike: shuffle to match monst...
# 28  A retro style space sim where you mine, trade,...
# 29  A Single and cooperative game for 4 players, y...
# 30  AngelStrike is an exciting 2D side-scrolling s...
# 31  In Koler, a rogue-lite stylized world, you hav...
# 32  Explore 8 immersive lanes and unlock 150+ uniq...
# 33  Answer the summons of the trumpets and bear th...
# 34  Five nights at Tinky's is a indie horror game,...
# 35  A rogue-lite tabletop that mixes card based ex...
# 36  We embody the spirit of The Dagda, king of the...
# 37  On the ominous date of 8/8/1888, the entire po...
# 38  A magical open world RPG, where your choices m...
# 39  A scientific experiment to create the ultimate...
# 40  Metro Manager LA is a strategy simulation game...
# 41  A lovely style of painting rogue-like games. I...
# 42  As the basis for an open-world action VR game,...
# 43  Be the first to reach the goal in this intense...
# 44  Tammy and Matthew dream of owning their own re...
# 45  Have you ever wanted to walk up to the clouds?...
# 46  Say hello (morning!) to a new kind of rhythm g...
# 47  Shinobi alert! Use your 7 shinobi weapons to s...
# 48  A PIONEER OF THE BULLET HELL GENRE BY TOAPLAN ...
# 49  Become an unstoppable force or suffer crushing...
#
#                                                 Genre
# 0                               [Free to Play, Indie]
# 1                             [Action, Casual, Indie]
# 2                    [Adventure, Indie, Early Access]
# 3                                     [Casual, Indie]
# 4                                [Action, Indie, RPG]
# 5             [Casual, Free to Play, Indie, Strategy]
# 6                                 [Action, Adventure]
# 7                                            [Action]
# 8                                   [Indie, Strategy]
# 9                                     [Action, Indie]
# 10                                    [Action, Indie]
# 11                                           [Casual]
# 12                [Action, Indie, Racing, Simulation]
# 13                         [Action, Adventure, Indie]
# 14                         [Adventure, Casual, Indie]
# 15             [Adventure, Casual, Indie, Simulation]
# 16                      [Action, Indie, Early Access]
# 17                                       [Indie, RPG]
# 18                    [Adventure, Casual, Simulation]
# 19                     [Casual, Free to Play, Sports]
# 20                                    [Action, Indie]
# 21                                        [Adventure]
# 22                                        [Adventure]
# 23                                           [Casual]
# 24                                            [Indie]
# 25               [Adventure, Casual, Indie, Strategy]
# 26                                    [Action, Indie]
# 27               [Adventure, Casual, Indie, Strategy]
# 28                 [Action, Adventure, Casual, Indie]
# 29  [Action, Massively Multiplayer, Simulation, Ea...
# 30                                    [Action, Indie]
# 31                 [Action, Indie, RPG, Early Access]
# 32                         [Casual, Sports, Strategy]
# 33                             [Simulation, Strategy]
# 34                 [Action, Adventure, Casual, Indie]
# 35                                    [RPG, Strategy]
# 36           [Action, Adventure, Free to Play, Indie]
# 37                     [Adventure, Indie, Simulation]
# 38    [Adventure, Free to Play, Indie, RPG, Strategy]
# 39                                           [Action]
# 40                             [Simulation, Strategy]
# 41                         [Adventure, Casual, Indie]
# 42                                           [Action]
# 43            [Action, Casual, Indie, Racing, Sports]
# 44                    [Adventure, Casual, Simulation]
# 45                         [Adventure, Casual, Indie]
# 46                                   [Action, Casual]
# 47                                           [Action]
# 48                                           [Action]
# 49                                           [Action]
